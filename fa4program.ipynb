# %% [markdown]
# <a href="https://colab.research.google.com/github/Briiieeee-M8/fa4prograactivity/blob/main/fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for num in range(0,21):
  if num % 2 == 0:
    continue
  else:
    print(num)
    num += 1

# %%
#passworc checker
CORRECT_PASSWORD = "goodbye"
incorrect_password = " "

while incorrect_password != CORRECT_PASSWORD:
  incorrect_password = input("enter your password")
  if incorrect_password != CORRECT_PASSWORD:
   print("incorrect password, try again")
  else:
    print("access granted")
    break

# %%
#display numbers from 1, 10 but
 #skip 4, does "nothing special" for 6, stops when loop reaches 8

for num in range(0, 11):
  if num % 4 == 0:
    continue
  else:
    print(num)
    num += 1
  if num == 6:
   pass
  if num == 8:
    break
